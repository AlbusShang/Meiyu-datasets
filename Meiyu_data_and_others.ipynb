# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbusShang/Meiyu-datasets/blob/main/Meiyu_data_and_others.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Installing Packages and Importing Functions

# %%
# !pip install netcdf4 xarray pens
# !pip install scipy==1.11.4  # to handle a dependency issue (date: 02-02-2024)
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.8/402.8 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 24.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 649.5/649.5 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import pens

# %%
# !pip install cftime
# !pip install netCDF4
# !pip install pyproj

# %%
# !pip install xarray

# %%
import xarray as xr

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
from datetime import datetime, timedelta
from cftime import date2num
from netCDF4 import Dataset
from pyproj import Proj

# %%
import netCDF4
from scipy.io import netcdf

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
from pathlib import Path
Meiyu_path = Path(os.getcwd())/'drive'/'MyDrive'/'Climate Research Project'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###1. Loading Meiyu Onset Date File

# %%
df1=pd.read_csv(Meiyu_path/'YangtzeMeiyuDate.txt',sep=' ')
df1
df2=pd.read_csv(Meiyu_path/'TaiyuanMeiyuDate.txt',sep=' ')
df2
df3=pd.read_csv(Meiyu_path/'DatongMeiyuDate.txt',sep=' ')
df3
df4=pd.read_csv(Meiyu_path/'YulinMeiyuDate.txt',sep=' ')

# %% [markdown]
# ## Yangtze River

# %%
# pre-industrial era correlation
df1_old=df1[df1['YEAR']<1880]
df1_old
# Out:
#        ID  VERS                                 NAME       LOCATION  PROXY  \
# 0    1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 1    1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 2    1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 3    1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 4    1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# ..    ...   ...                                  ...            ...    ...
# 139  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 140  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 141  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 142  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 143  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
#
# ...

# %%
#industrial era correlation
df1_new=df1[df1['YEAR']>=1880]
df1_new
# Out:
#        ID  VERS                                 NAME       LOCATION  PROXY  \
# 144  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 145  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 146  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 147  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 148  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# ..    ...   ...                                  ...            ...    ...
# 260  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 261  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 262  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 263  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
# 264  1401  V1.0  Wind_Yangtze_River_Meiyu_onset_date  Yangtze_River  Meiyu
#
# ...

# %%
nino34_med_df_old=nino34_med_df[nino34_med_df['time']<1880]
nino34_med_df_old

# %%
nino34_med_df_new=nino34_med_df[nino34_med_df['time']>=1880]
nino34_med_df_new
# Out:
#      time     ens.0
# 144  1880 -0.464450
# 145  1881 -0.272627
# 146  1882 -0.334942
# 147  1883  0.103450
# 148  1884  0.777679
# ..    ...       ...
# 260  1996  0.207255
# 261  1997  2.034703
# 262  1998  0.840616
# 263  1999 -0.254855
# 264  2000 -0.369170
#
# [121 rows x 2 columns]

# %%
with sns.axes_style("ticks"):
  plt.scatter(df1_old['VALUE'],nino34_med_df_old['ens.0'])
  plt.title('Earlier Meiyu and ENSO Correlation (Yangtze River)')
  plt.xlabel('Onset Date')
  plt.ylabel('Nino 3.4 (K)')
  plt.savefig(Meiyu_path/'1736-1879 correlation-Yangtze.png')

# %%
oldDF=pd.DataFrame()
oldDF.insert(0,'VALUE',df1_old['VALUE'])
oldDF.insert(1,'Nino3.4_Median',nino34_med_df_old['ens.0'])
oldDF
# Out:
#      VALUE  Nino3.4_Median
# 0    171.0        0.091795
# 1    174.0       -0.080206
# 2    164.0       -0.130813
# 3    162.0        0.500051
# 4    156.0        0.053323
# ..     ...             ...
# 139  155.0        0.266767
# 140  165.0        0.227014
# 141  178.0        0.575148
# 142  172.0        0.342457
# 143  161.0       -0.700243
#
# [144 rows x 2 columns]

# %%
oldDF.corr()
# Out:
#                    VALUE  Nino3.4_Median
# VALUE           1.000000        0.027447
# Nino3.4_Median  0.027447        1.000000

# %%
newDF=pd.DataFrame()
newDF.insert(0,'VALUE',df1_new['VALUE'])
newDF.insert(1,'Nino3.4_Median',nino34_med_df_new['ens.0'])
newDF
newDF.corr()
# Out:
#                    VALUE  Nino3.4_Median
# VALUE           1.000000        0.118037
# Nino3.4_Median  0.118037        1.000000

# %%
with sns.axes_style("ticks"):
  plt.scatter(df1_new['VALUE'],nino34_med_df_new['ens.0'])
  plt.title('Later Meiyu and ENSO Correlation (Yangtze River)')
  plt.xlabel('Onset Date')
  plt.ylabel('Nino 3.4 (K)')
  plt.savefig(Meiyu_path/'1880-2000 correlation-Yangtze.png')

# %%
with sns.axes_style("ticks"):
  plt.figure(figsize=(10,4))
  plt.plot(df1['YEAR'], df1['VALUE'],marker='o',alpha=0.5,linestyle='None',markersize = 5.0)
  plt.plot(df2['YEAR'], df2['VALUE'],marker='o',alpha=0.5,linestyle='None',markersize = 5.0)
  plt.plot(df4['YEAR'], df4['VALUE'],marker='o',alpha=0.5,linestyle='None',markersize = 5.0)
  #plt.axvline(x=1757)
  #plt.axvline(x=1806)
  plt.xlabel('Year')
  plt.ylabel('Meiyu Onset Date')
  plt.legend(['Yangtze River','Taiyuan','Yulin'])
  plt.title('Meiyu Onset Date Since 1736')
  plt.savefig(Meiyu_path/'Meiyu Onset Date.png')
  LMR = pens.EnsembleTS().load_nc(tos_new, var='nino3.4',time_name='year')
  LMR.label = 'LMR (Nino 3.4)'
  LMR.linestyle='o'
  LMR.alpha=.5
  LMR.value_name = 'Index'
  LMR.time_unit = 'year CE'
  LMR.value_unit='K'
  LMR.plot_figsize=(10,20)
  LMR.plot_qs()
  plt.savefig(Meiyu_path/'Nino3.4(1736-2000).png')

# %% [markdown]
# ##Taiyuan

# %%
df2
# Out:
#        ID  VERS                           NAME LOCATION  PROXY    LON   LAT  \
# 0    1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 1    1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 2    1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 3    1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 4    1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# ..    ...   ...                            ...      ...    ...    ...   ...
# 160  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 161  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 162  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 163  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 164  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
#
# ...

# %%
df2_old=df2[df2['YEAR']<1880]
df2_old
df2_new=df2[df2['YEAR']>=1880]
df2_new
# Out:
#        ID  VERS                           NAME LOCATION  PROXY    LON   LAT  \
# 144  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 145  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 146  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 147  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 148  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 149  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 150  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 151  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 152  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 153  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# 154  1403  V1.0  Wind_Taiyuan_Meiyu_onset_date  Taiyuan  Meiyu  111.5  38.5
# ...

# %%
nino34_med_df2=nino34_med_df[nino34_med_df['time']<1901]
nino34_med_df2
# Out:
#      time     ens.0
# 0    1736  0.091795
# 1    1737 -0.080206
# 2    1738 -0.130813
# 3    1739  0.500051
# 4    1740  0.053323
# ..    ...       ...
# 160  1896  0.859587
# 161  1897 -0.526419
# 162  1898 -0.531616
# 163  1899  0.038845
# 164  1900  0.150155
#
# [165 rows x 2 columns]

# %%
with sns.axes_style("ticks"):
  plt.scatter(df2['VALUE'],nino34_med_df2['ens.0'])
  plt.title('Meiyu and ENSO Correlation (Taiyuan)')
  plt.xlabel('Onset Date')
  plt.ylabel('Nino 3.4 (K)')
  plt.savefig(Meiyu_path/'1736-1900 correlation-Taiyuan.png')

# %%
taiyuan=pd.DataFrame()
taiyuan.insert(0,'VALUE',df2['VALUE'])
taiyuan.insert(1,'Nino3.4_Median',nino34_med_df2['ens.0'])
taiyuan
taiyuan.corr()
# Out:
#                   VALUE  Nino3.4_Median
# VALUE           1.00000         0.01852
# Nino3.4_Median  0.01852         1.00000

# %% [markdown]
# ## Datong

# %%
df3
# Out:
#        ID  VERS                          NAME LOCATION  PROXY    LON   LAT  \
# 0    1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
# 1    1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
# 2    1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
# 3    1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
# 4    1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
# ..    ...   ...                           ...      ...    ...    ...   ...
# 160  1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
# 161  1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
# 162  1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
# 163  1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
# 164  1405  V1.0  Wind_Datong_Meiyu_onset_date   Datong  Meiyu  111.5  38.5
#
# ...

# %%
with sns.axes_style("ticks"):
  plt.scatter(df3['VALUE'],nino34_med_df2['ens.0'])
  plt.title('Meiyu and ENSO Correlation (Datong)')
  plt.xlabel('Onset Date')
  plt.ylabel('Nino 3.4 (K)')
  plt.savefig(Meiyu_path/'1736-1900 correlation-Datong.png')

# %%
datong=pd.DataFrame()
datong.insert(0,'VALUE',df3['VALUE'])
datong.insert(1,'Nino3.4_Median',nino34_med_df2['ens.0'])
datong
datong.corr()
# Out:
#                   VALUE  Nino3.4_Median
# VALUE           1.00000         0.09336
# Nino3.4_Median  0.09336         1.00000

# %% [markdown]
# ## Yulin

# %%
df4
# Out:
#        ID  VERS                         NAME LOCATION  PROXY    LON   LAT  \
# 0    1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
# 1    1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
# 2    1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
# 3    1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
# 4    1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
# ..    ...   ...                          ...      ...    ...    ...   ...
# 160  1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
# 161  1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
# 162  1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
# 163  1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
# 164  1407  V1.0  Wind_Yulin_Meiyu_onset_date    Yulin  Meiyu  111.5  38.5
#
#      ALT  YEAR  MONTH  ... REF_PERIOD_START  REF_PERIOD_END REFDATA MODEL  \
# ...

# %%
with sns.axes_style("ticks"):
  plt.scatter(df4['VALUE'],nino34_med_df2['ens.0'])
  plt.title('Meiyu and ENSO Correlation (Yulin)')
  plt.xlabel('Onset Date')
  plt.ylabel('Nino 3.4 (K)')
  plt.savefig(Meiyu_path/'1736-1900 correlation-Yulin.png')

# %%
yulin=pd.DataFrame()
yulin.insert(0,'VALUE',df4['VALUE'])
yulin.insert(1,'Nino3.4_Median',nino34_med_df2['ens.0'])
yulin
yulin.corr()
# Out:
#                   VALUE  Nino3.4_Median
# VALUE           1.00000         0.04137
# Nino3.4_Median  0.04137         1.00000

# %% [markdown]
# ###2. Loading files from  LMRonline

# %%
pens.set_style('journal_nogrid')

# %%
tas= Meiyu_path/'tas_sfc_indices.nc'
tas1=xr.open_dataset(tas)
tas1
# Out:
# <xarray.Dataset> Size: 160MB
# Dimensions:    (year: 1001, mc_iteration: 50, ensemble_member: 100)
# Coordinates:
#   * year       (year) int64 8kB 1000 1001 1002 1003 1004 ... 1997 1998 1999 2000
# Dimensions without coordinates: mc_iteration, ensemble_member
# Data variables:
#     europe     (mc_iteration, ensemble_member, year) float64 40MB ...
#     glob_mean  (mc_iteration, ensemble_member, year) float64 40MB ...
#     nh         (mc_iteration, ensemble_member, year) float64 40MB ...
#     sh         (mc_iteration, ensemble_member, year) float64 40MB ...

# %%
LMR = pens.EnsembleTS().load_nc(tas, var='nh',time_name='year')
LMR.label = 'LMR Reconstruction'
LMR.value_name = 'NH Mean Temp'
LMR.time_unit = 'year CE'
LMR.plot_qs()
# Out:
# (<Figure size 1000x400 with 1 Axes>,
#  <Axes: title={'center': 'LMR Reconstruction'}, xlabel='time [year CE]', ylabel='NH Mean Temp'>)

# %%
rsut= Meiyu_path/'rsut_toa_indices.nc'
rsut1=xr.open_dataset(rsut)
rsut1
# Out:
# <xarray.Dataset> Size: 40MB
# Dimensions:    (year: 1001, mc_iteration: 50, ensemble_member: 100)
# Coordinates:
#   * year       (year) int64 8kB 1000 1001 1002 1003 1004 ... 1997 1998 1999 2000
# Dimensions without coordinates: mc_iteration, ensemble_member
# Data variables:
#     glob_mean  (mc_iteration, ensemble_member, year) float64 40MB ...

# %%
ensmean= Meiyu_path/'spatial_ens_mean.nc'
ensmean1=xr.open_dataset(ensmean)
ensmean1
# Out:
# <xarray.Dataset> Size: 649MB
# Dimensions:     (lon: 180, lat: 90, time: 1001)
# Coordinates:
#   * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#   * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   * time        (time) int64 8kB 1000 1001 1002 1003 ... 1997 1998 1999 2000
#     lon_grid    (lat, lon) float64 130kB ...
#     lat_grid    (lat, lon) float64 130kB ...
# Data variables:
#     pr_sfc      (time, lat, lon) float32 65MB ...
#     psl_sfc     (time, lat, lon) float32 65MB ...
#     rlut_toa    (time, lat, lon) float32 65MB ...
#     rsut_toa    (time, lat, lon) float32 65MB ...
#     tas_sfc     (time, lat, lon) float32 65MB ...
#     zg_500hPa   (time, lat, lon) float32 65MB ...
#     sos_sfc     (time, lat, lon) float32 65MB ...
#     tos_sfc     (time, lat, lon) float32 65MB ...
#     zos_sfc     (time, lat, lon) float32 65MB ...
#     ohc_0-700m  (time, lat, lon) float32 65MB ...

# %%
tos= Meiyu_path/'tos_sfc_indices.nc'
tos1=xr.open_dataset(tos)
tos1
# Out:
# <xarray.Dataset> Size: 240MB
# Dimensions:    (year: 1001, mc_iteration: 50, ensemble_member: 100)
# Coordinates:
#   * year       (year) int64 8kB 1000 1001 1002 1003 1004 ... 1997 1998 1999 2000
# Dimensions without coordinates: mc_iteration, ensemble_member
# Data variables:
#     glob_mean  (mc_iteration, ensemble_member, year) float64 40MB ...
#     natlantic  (mc_iteration, ensemble_member, year) float64 40MB ...
#     nino3.4    (mc_iteration, ensemble_member, year) float64 40MB ...
#     nino3      (mc_iteration, ensemble_member, year) float64 40MB ...
#     nino4      (mc_iteration, ensemble_member, year) float64 40MB ...
#     pdo        (mc_iteration, ensemble_member, year) float64 40MB ...

# %%
new_tos=tos1.sel(
    year=slice('1736', '2000'))
new_tos
# Out:
# <xarray.Dataset> Size: 64MB
# Dimensions:    (year: 265, mc_iteration: 50, ensemble_member: 100)
# Coordinates:
#   * year       (year) int64 2kB 1736 1737 1738 1739 1740 ... 1997 1998 1999 2000
# Dimensions without coordinates: mc_iteration, ensemble_member
# Data variables:
#     glob_mean  (mc_iteration, ensemble_member, year) float64 11MB ...
#     natlantic  (mc_iteration, ensemble_member, year) float64 11MB ...
#     nino3.4    (mc_iteration, ensemble_member, year) float64 11MB ...
#     nino3      (mc_iteration, ensemble_member, year) float64 11MB ...
#     nino4      (mc_iteration, ensemble_member, year) float64 11MB ...
#     pdo        (mc_iteration, ensemble_member, year) float64 11MB ...

# %%
tos_new=new_tos.to_netcdf()

# %%
LMR = pens.EnsembleTS().load_nc(tos_new, var='nino3.4',time_name='year')
LMR.label = 'LMR (Nino 3.4)'
LMR.linestyle='o'
LMR.alpha=.5
LMR.value_name = 'Index'
LMR.time_unit = 'year CE'
LMR.value_unit='K'
LMR.plot_figsize=(10,20)
LMR.plot_qs()
plt.savefig(Meiyu_path/'Nino3.4(1736-2000).png')

# %%
nino34_med=LMR.get_median()
nino34_med.plot()
nino34_med_df = nino34_med.to_df()
#nino34_med_df.columns = ['nino34_med']
nino34_med_df.tail()
# Out:
#      time     ens.0
# 260  1996  0.207255
# 261  1997  2.034703
# 262  1998  0.840616
# 263  1999 -0.254855
# 264  2000 -0.369170

# %%
}LMR = pens.EnsembleTS().load_nc(tos_new, var='nino3',time_name='year')
LMR.label = 'LMR (Nino 3)'
LMR.value_name = 'Index'
LMR.time_unit = 'year CE'
LMR.value_unit='K'
LMR.plot_qs()
plt.savefig(Meiyu_path/'Nino3(1736-2000).png')

# %%
LMR = pens.EnsembleTS().load_nc(tos_new, var='nino4',time_name='year')
LMR.label = 'LMR (Nino 4)'
LMR.value_name = 'Index'
LMR.time_unit = 'year CE'
LMR.value_unit='K'
LMR.plot_qs()
plt.savefig(Meiyu_path/'Nino4(1736-2000).png')

# %%
psl= Meiyu_path/'psl_sfc_indices.nc'
psl1=xr.open_dataset(psl)
psl1
# Out:
# <xarray.Dataset> Size: 200MB
# Dimensions:  (year: 1001, mc_iteration: 50, ensemble_member: 100)
# Coordinates:
#   * year     (year) int64 8kB 1000 1001 1002 1003 1004 ... 1997 1998 1999 2000
# Dimensions without coordinates: mc_iteration, ensemble_member
# Data variables:
#     45s      (mc_iteration, ensemble_member, year) float64 40MB ...
#     65s      (mc_iteration, ensemble_member, year) float64 40MB ...
#     darwin   (mc_iteration, ensemble_member, year) float64 40MB ...
#     npi      (mc_iteration, ensemble_member, year) float64 40MB ...
#     tahiti   (mc_iteration, ensemble_member, year) float64 40MB ...

# %%
ensvar= Meiyu_path/'spatial_ens_var.nc'
ensvar1=xr.open_dataset(ensvar)
ensvar1
# Out:
# <xarray.Dataset> Size: 649MB
# Dimensions:     (lon: 180, lat: 90, time: 1001)
# Coordinates:
#   * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     lon_grid    (lat, lon) float64 130kB ...
#   * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#     lat_grid    (lat, lon) float64 130kB ...
#   * time        (time) int64 8kB 1000 1001 1002 1003 ... 1997 1998 1999 2000
# Data variables:
#     pr_sfc      (time, lat, lon) float32 65MB ...
#     psl_sfc     (time, lat, lon) float32 65MB ...
#     rlut_toa    (time, lat, lon) float32 65MB ...
#     rsut_toa    (time, lat, lon) float32 65MB ...
#     tas_sfc     (time, lat, lon) float32 65MB ...
#     zg_500hPa   (time, lat, lon) float32 65MB ...
#     sos_sfc     (time, lat, lon) float32 65MB ...
#     tos_sfc     (time, lat, lon) float32 65MB ...
#     zos_sfc     (time, lat, lon) float32 65MB ...
#     ohc_0-700m  (time, lat, lon) float32 65MB ...

# %%
ohc= Meiyu_path/'ohc_0-700m_indices.nc'
ohc1=xr.open_dataset(ohc)
ohc1
# Out:
# <xarray.Dataset> Size: 40MB
# Dimensions:    (year: 1001, mc_iteration: 50, ensemble_member: 100)
# Coordinates:
#   * year       (year) int64 8kB 1000 1001 1002 1003 1004 ... 1997 1998 1999 2000
# Dimensions without coordinates: mc_iteration, ensemble_member
# Data variables:
#     glob_mean  (mc_iteration, ensemble_member, year) float64 40MB ...

# %%
rlut= Meiyu_path/'rlut_toa_indices.nc'
rlut1=xr.open_dataset(rlut)
rlut1
# Out:
# <xarray.Dataset> Size: 40MB
# Dimensions:    (year: 1001, mc_iteration: 50, ensemble_member: 100)
# Coordinates:
#   * year       (year) int64 8kB 1000 1001 1002 1003 1004 ... 1997 1998 1999 2000
# Dimensions without coordinates: mc_iteration, ensemble_member
# Data variables:
#     glob_mean  (mc_iteration, ensemble_member, year) float64 40MB ...
